# %%
import pandas as pd
import numpy as np

df = pd.read_csv("ptbxl_database.csv")

for FeatureName, NanCount in df.isnull().sum().items():
    NanPercentage: float = (NanCount/df.shape[0]) * 100
    print(f"{FeatureName}: {NanPercentage}%")
# Out:
# ecg_id: 0.0%
# patient_id: 0.0%
# age: 0.0%
# sex: 0.0%
# height: 68.00770677554017%
# weight: 56.782421211982204%
# nurse: 6.757190696820955%
# site: 0.07798522868021468%
# device: 0.0%
# recording_date: 0.0%
# report: 0.0%
# scp_codes: 0.0%
# heart_axis: 38.84581861553282%
# infarction_stadium1: 74.25569980274325%
# infarction_stadium2: 99.52750126152576%
# validated_by: 43.020322033120785%
# second_opinion: 0.0%
# initial_autogenerated_report: 0.0%
# validated_by_human: 0.0%
# baseline_drift: 92.66938850405982%
# static_noise: 85.04518555897059%
# burst_noise: 97.18794440111932%
# electrodes_problems: 99.86237900821139%
# extra_beats: 91.05922290013304%
# pacemaker: 98.66507637965044%
# strat_fold: 0.0%
# filename_lr: 0.0%
# filename_hr: 0.0%
